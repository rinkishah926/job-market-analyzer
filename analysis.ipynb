# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Narin\AppData\Local\Programs\Python\Python313\python.exe

# %%
import pandas as pd

# %%
df= pd.read_csv("data/jobs.csv")

# %%
df.head()
# Out:
#            job_title     company       location  salary  \
# 0       Data Analyst    ABC Corp       New York   70000
# 1     Data Scientist     XYZ Inc  San Francisco  120000
# 2   Business Analyst    TechSoft        Chicago   80000
# 3  Software Engineer  Innovatech        Seattle  110000
# 4       Data Analyst   DataWorks       New York   75000
#
#                                      description
# 0          Looking for Python, SQL, Excel skills
# 1  Machine learning, Python, TensorFlow required
# 2        Strong Excel, SQL, communication skills
# 3    Java, Spring Boot, microservices experience
# 4                  SQL, Tableau, Python required

# %%
df.columns
# Out:
# Index(['job_title', 'company', 'location', 'salary', 'description'], dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   job_title    15 non-null     str
#  1   company      15 non-null     str
#  2   location     15 non-null     str
#  3   salary       15 non-null     int64
#  4   description  15 non-null     str
# dtypes: int64(1), str(4)
# memory usage: 732.0 bytes

# %%
df.describe()
# Out:
#               salary
# count      15.000000
# mean   102266.666667
# std     22597.302831
# min     70000.000000
# 25%     81000.000000
# 50%    110000.000000
# 75%    119000.000000
# max    135000.000000

# %%
df.isnull().sum()
# Out:
# job_title      0
# company        0
# location       0
# salary         0
# description    0
# dtype: int64

# %%
df['job_title'].value_counts()
# Out:
# job_title
# Data Analyst                 3
# Business Analyst             3
# Software Engineer            3
# Data Scientist               2
# Machine Learning Engineer    2
# Data Engineer                2
# Name: count, dtype: int64

# %%
df['location'].value_counts()
# Out:
# location
# New York         4
# Chicago          3
# San Francisco    2
# Seattle          2
# Boston           2
# Austin           2
# Name: count, dtype: int64

# %%
df.groupby('job_title')['salary'].mean()
# Out:
# job_title
# Business Analyst              82333.333333
# Data Analyst                  72333.333333
# Data Engineer                113500.000000
# Data Scientist               119000.000000
# Machine Learning Engineer    132500.000000
# Software Engineer            113333.333333
# Name: salary, dtype: float64

# %%
skills = ['Python', 'SQL', 'Excel', 'Tableau', 'Java', 'AWS']

for skill in skills:
    print(skill, df['description'].str.contains(skill, case=False).sum())
# Out:
# Python 8
# SQL 7
# Excel 5
# Tableau 1
# Java 3
# AWS 1

# %%
import matplotlib.pyplot as plt

# %%
df['job_title'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='job_title'>

# %%
plt.title('Top Job Roles')
plt.xlabel('Job Title')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['job_title'].value_counts().plot(kind='bar')
plt.title('Top Job Roles')
plt.xlabel('Job Title')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
